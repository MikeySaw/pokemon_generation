# %%
import random

import matplotlib.pyplot as plt
import torch

# Importing the used dataset subclass is needed to reconstruct the dataset
from src.data.make_dataset import PokemonDataset  # noqa

# %%
import os

os.chdir("..")

# %%
data_path = "data/processed/pokemon.pth"
dataset = torch.load(data_path)

# %%
plt.imshow(dataset[random.randint(0, len(dataset))].permute(1, 2, 0))
None
